# %%
class Library:
    def __init__(self, title, author, pages):
        print(self)
        
    # def books():
    #     available = [
    #         {
    #             "id":1
    #             "name":"It End With Us",
    #             "author":"parkson",
    #             "published":2019,
    #         },
    #         {
    #             "id":2
    #             "name":"Black Panther",
    #             "author":"Barddly",
    #             "published":2018,
    #         },
    #         {
    #             "id":3
    #             "name":"The Dark Knight Rises",
    #             "author":"Leon",
    #             "published":2020,
    #         }
    #     ]
    #     return available
    

 

data = Library()

# borrow = input("Enter the number to borrow the book")
