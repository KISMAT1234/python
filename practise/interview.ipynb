# %%
i = 1
while i <= 3:
    print("*" * i)
    i += 1
# Out:
# *
# **
# ***

# %%
data = input("Enter the value")
vowels = ['a', 'e', 'i', 'o', 'u']

for i in data:
   if i in vowels:
    print(i, "is a vowel")
# Out:
# a is a vowel
# e is a vowel

# %%
a = [1, 2, 3, 4,1, 5,6,8,4]

b = set(a)
print(list(b))
# Out:
# [1, 2, 3, 4, 5, 6, 8]
