# %%
a = {
    "name":"roshan",
    "age":1
}
print(a)
print(a.keys())
print(a.values())
print(a['name'])
print(a['age'])
# Out:
# {'name': 'roshan', 'age': 1}
# dict_keys(['name', 'age'])
# dict_values(['roshan', 1])
# roshan
# 1

# %%
b = {
    "data":(1,2,3,4),
    "pw":"hello",
    "car": {
        "color":"okay",
        "model":{
            "first":"X"
        }
    }
}

print(b["car"]["model"]["first"])
print(b.pop("data"))
print(b)
# Out:
# X
# (1, 2, 3, 4)
# {'pw': 'hello', 'car': {'color': 'okay', 'model': {'first': 'X'}}}
