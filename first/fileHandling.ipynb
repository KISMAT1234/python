# %%
value = open("sample.txt", "r")
# value.write("I agree messi is the greatest player in the world")
# value.close()
content = value.read()
line = value.readline()
liness = value.readlines()
# print(content)
print(line, "Only line")
print(liness)
# Out:
#  Only line
# []

# %%
with open("sample.txt", "r") as productFile:
    content = productFile.read()
    print(content)
# Out:
# I agree messi is the greatest player in the world. And ronaldo is the second player in the world.

# %%
class Dog:
