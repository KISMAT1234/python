# %%
player = ["Rahul", "Rohit", "Nishant"]
for value in player:
    print(player.index(value))
    print(value)
# Out:
# 0
# Rahul
# 1
# Rohit
# 2
# Nishant

# %%
for value in range(1, 10, 2):
    temp = value 
    print(temp + value)
# Out:
# 2
# 6
# 10
# 14
# 18

# %%
data = ["a", "b", "c", "d", "e"]
for i in range(1, 4):
    print(data[i])
# Out:
# b
# c
# d

# %%
data = input("Enter the data: ")
s = data.split()
print(s)
vowels = ["aeiouAEIOU"]
for value in s:
    if(value)


# for i in exch:
#     if(i )
# Out:
# ['my', 'name', 'is', 'kisamt']
