# %%
a = [10, 20, 30, 40, 50]
print(a[2])
print(a[4])
print(a[3:])
print(a[::-1])
# Out:
# 30
# 50
# [40, 50]
# [50, 40, 30, 20, 10]

# %%
colors = ['red', 'blue', 'green', 'yellow', 'purple', 'orange']
a = colors[:3]
b = colors[4:6]
print(a,b)
# Out:
# ['red', 'blue', 'green'] ['purple', 'orange']

# %%
numbers = [1,2,3]
numbers.append(4)
numbers.insert(0, 0)
numbers.remove(2)
print(numbers)
# Out:
# [0, 1, 3, 4]

# %%
list1 = [1,2]
list2 = [3,4]
list3 = [5,6]
combine = list1 + list2
print(combine)

three = list3 * 3
print(three)
# Out:
# [1, 2, 3, 4]
# [5, 6, 5, 6, 5, 6]

# %%
detail = ("kismat", 21, "kathmandu")
print(detail[0])
print(detail[1])
print(detail[2])
# Out:
# kismat
# 21
# kathmandu

# %%
numbers = (1,2,3,2,4,2,5)
count = numbers.count(2)
print(count)
index = numbers.index(3)
print(index)
# Out:
# 3
# 2

# %%
book = {
   "title":"python",
   "author":"jK",
   "year":2000,
   "pages":300
}
print(book["author"])
print(book["year"])
# Out:
# jK
# 2000

# %%
student = {
    "name":"John",
    "grade":"A"
}
student.setdefault("age",20)
print(student)
change = student["grade"] = "A+"
print(student)
del student["name"]
print(student)
# Out:
# {'name': 'John', 'grade': 'A', 'age': 20}
# {'name': 'John', 'grade': 'A+', 'age': 20}
# {'grade': 'A+', 'age': 20}

# %%
fruits =  {"apple", "banana", "orange"}
fruits.add("grape")
fruits.remove("banana")
print(fruits)
isCheck = "apple" in fruits
print(isCheck)
# Out:
# {'grape', 'orange', 'apple'}
# True

# %%
string = "hello , world"
print(string)

char_list = list(string)
split_list = string.split()
print(split_list)
print(char_list)
# Out:
# hello , world
# ['hello', ',', 'world']
# ['h', 'e', 'l', 'l', 'o', ' ', ',', ' ', 'w', 'o', 'r', 'l', 'd']

# %%
string1 = "programming"
string2 = "algorithm"

set1 = set(string1)
print(set1)
set2 = set(string2)
intersection = set1 & set2
print(intersection)
union = set1 | set2
print(union)
# Out:
# {'i', 'o', 'r', 'g', 'p', 'a', 'm', 'n'}
# {'i', 'r', 'o', 'g', 'a', 'm'}
# {'i', 'l', 'o', 'r', 't', 'g', 'h', 'p', 'a', 'm', 'n'}
