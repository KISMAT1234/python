# %%
num = int(input("Enter a number:"))
for i in range(2, num):
    print(i)
    if num % i == 0 :
       print("Number is prime number")
    else: 
       print("Number is not prime number")

# %%
num = "Start"
vowels = ['a','e','i','o','u']
count = 0
for i in num:
    if i in vowels:
        count+=1
        print(i)
# Out:
# a

# %%
value = [1,2,3,4,5,6,7,8,9]
ocount = 0
ecount = 0

for i in value:
    if(i % 2 == 0):
        print(f"Value is even ", i)
        ecount += 1
    else:
        print(f"Value is odd ", i)
        ocount += 1

print(f"Even count is {ecount} and Odd count is {ocount}")
# Out:
# Value is odd  1
# Value is even  2
# Value is odd  3
# Value is even  4
# Value is odd  5
# Value is even  6
# Value is odd  7
# Value is even  8
# Value is odd  9
# Even count is 4 and Odd count is 5

# %%
def character(value):
    print(value)
    empty = {}
    for i in value:
        print(i)
        empty[i] = value.index(i)
    return empty
        

key = character("nepal")
print(key)
# Out:
# nepal
# n
# e
# p
# a
# l
# {'n': 0, 'e': 1, 'p': 2, 'a': 3, 'l': 4}
