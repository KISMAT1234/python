# %%
data = lambda color: print(color)
data("red")
# Out:
# red

# %%
data = [10,5,3,6,7]
ev = list(filter(lambda x : x % 2 == 0, data))
print("Even ", ev)
# Out:
# Even  [10, 6]

# %%
data = (1,2,3,4,2,5,6)
# a = list(map(lambda value: value % 2 == 0, data))
a = list(map(lambda value: value * 2, data))
print(a)
# Out:
# [2, 4, 6, 8, 4, 10, 12]

# %%
from math import *
import statistics
import os
result = sqrt(25)
print(result)
print(os.name)
# Out:
# 5.0
# nt

# %%
import json
person = {
    "name": "Kismat",
    "age": 25,
    "gender": "male",
}

data = json.dumps(person)
print(data)
print(type(data), "t")

json = json.loads(data)
print(json)
print(type(json))
# Out:
# {"name": "Kismat", "age": 25, "gender": "male"}
# <class 'str'> t
# {'name': 'Kismat', 'age': 25, 'gender': 'male'}
# <class 'dict'>

# %%
try:
    num = input("Enter the name: ")
    print(num, "value")
    print(type(num), "type")
    if not num:
        print("inside")
        raise ValueError("error")

except ValueError as a : 
    print("Please enter the name")
finally: 
    print("Thank you")
# Out:
# 10 value
# <class 'str'> type
# Thank you
